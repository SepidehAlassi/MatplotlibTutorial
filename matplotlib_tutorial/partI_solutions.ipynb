# %% [markdown]
# # Matplotlib Tutorial EuroSciPy 2016
# ## Part I:
#
# Sepideh Alassi, University of Basel
# Susanne Greiner, Würth Phoenix S.r.l.

# %% [markdown]
# Matplotlib is a library for plotting in Python, **matplotlib.pyplot** includes commands which are very similar to MATLAB commands, hence makes plotting with Python easier for beginners.

# %% [markdown]
# ## 1. Basic Plotting

# %% [markdown]
# In order to see the resulting plots, matplotlib should be inlined in the first cell of IPython.

# %%
# %matplotlib inline

# %% [markdown]
#  To use the matplotlib functions matplotlib should be imported as **import matplotlib**,but by importing the **matplotlib.pyplot** one has access to all MATLB like commands of Pyplot.

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# **Plot()** command draws the plot, and is a versatile command which accepts arbitrary number of arguments.  In order to see the plots **show()** command should be used. One can easily give legend information to the plots by **title()**, **xlabel()**, **ylabel()**

# %%
plt.plot([-1,0,1])
# to see the docu of function use ?
#plt.plot?
#help(plt.plot)
plt.title("simple plot")
plt.xlabel("x values")
plt.ylabel("y values")
plt.show()

# %% [markdown]
# By giving a single list of numbers, matplotlib assumes the values in list as y-values and auto-generates a list of x-values with the same length (here 3).In Python indecies start with 0, that is why generated x values are [0,1,2].

# %% [markdown]
# #### Exercise 1:
# Plot x=y , $x\in[-1,0,1]$ , give axes a label

# %%
plt.plot([-1,0,1], [-1,0,1])
plt.xlabel('x')
plt.ylabel('y')

# %% [markdown]
# ### 1.1. Controlling line properties and Formatting

# %% [markdown]
# The **axis()** command takes a list of [xmin, xmax, ymin, ymax] and specifies the visible limits of axes. The lines are drawn by default in "b-" (solid line in blue) format, any other MATLAB line formatting can be specified.

# %%
plt.plot([-1,0,1], [-2,0,2], 'r--')
plt.axis([-1,1,-2,2])
# Out:
# [-1, 1, -2, 2]

# %% [markdown]
# #### Exercise 2:
# Change the color of plot above to green, and the linestyle to dashdot.

# %%
plt.plot([-1,0,1], [-2,0,2], 'g-.')
plt.axis([-1,1,-2,2])
# Out:
# [-1, 1, -2, 2]

# %% [markdown]
# There are other ways to specify the line formats, for example by using keywords such as **linewidth** etc as an argument of plot() function.

# %%
import numpy as np
X = np.linspace(-np.pi , np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)
plt.plot(X,C, color="green", linewidth=2.0, linestyle="dotted")
#color="red", linestyle="circles"
plt.plot(X,S, 'ro')

# %% [markdown]
# #### Exercise 3:
# change the linewidth of your plot in exercise 2

# %%
plt.plot([-1,0,1], [-2,0,2], 'g-.', linewidth=4)
plt.axis([-1,1,-2,2])
# Out:
# [-1, 1, -2, 2]

# %% [markdown]
# **setp()** function is used to set properties for multiple figures

# %%
lines= plt.plot(X,S,X,C)
plt.setp(lines, color='cyan',linewidth='2.0')
# Out:
# [None, None, None, None]

# %% [markdown]
# Texts can be added to the plots as a text placed by **text()** in arbitrary position. **annotate()** gives the possibility of annotating points on the plot. In order to improve the scaling of the plots limits can be specified for the axes by **xlim()**, and **ylim()**.

# %%
plt.plot(X,C, 'b--')
t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color ='blue', linewidth=1.5, linestyle="--")
# adding dot to the specific point
plt.scatter([t,],[np.cos(t),], 50, color ='blue')
#annotating a point in plot
plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(-10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
# adding text to plot
plt.text(0,0,'sin(X)',fontsize=12, color='red')

plt.plot(X,S, 'r')
plt.plot([t,t],[0,np.sin(t)], color ='red', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.sin(t),], 50, color ='red')

plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-80, -40), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
#text with arrow
plt.annotate('cos(X)',color='blue', xy=(-1,0.5), xytext=(-3,0.5), arrowprops=dict(facecolor='blue', shrink=0.05))
plt.xlim(-4.0, 4.0)
plt.ylim(-2.0,2.0)
# Out:
# (-2.0, 2.0)

# %% [markdown]
# #### Exercise 4:
# Plot $y=tan^{-1}(x) , x\in[-\pi, \pi]$, set proper limits for x, and y values. Annotate point $x=0$

# %%
X_t=np.linspace(-np.pi, np.pi)
T=np.arctan(X_t)
plt.plot(X_t,T)
plt.ylim(-1.6,1.6)
plt.xlim(-3.5,3.5)

plt.scatter(0,0, 50, color ='red')

plt.annotate(r'$\tan^{-1}(0)=0$',
             xy=(0, 0), xycoords='data',
             xytext=(-80, 20), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# %% [markdown]
# ### 1.2. Adding legend
# Legends help in understanding the plots, adding a legend to a plot only requires adding the keyword argument label (that will be used in the legend box) to the plot commands.

# %%
plt.plot(X,S, '--r', linewidth=2.0, label="Sine")
plt.plot(X,C, color="green", linewidth=2.0, label="Cosine")
# add legend , frameone=False means no frame around legend
plt.legend(loc='upper left', frameon=False)

# %% [markdown]
# #### Exercise 5:
# Add legend to your plot of Exercise 4

# %%
X_t=np.linspace(-np.pi, np.pi)
T=np.arctan(X_t)
plt.plot(X_t,T, label='arctan')
plt.ylim(-1.6,1.6)
plt.xlim(-3.5,3.5)

plt.scatter(0,0, 50, color ='red')

plt.annotate(r'$\tan^{-1}(0)=0$',
             xy=(0, 0), xycoords='data',
             xytext=(-80, 20), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.legend(loc='upper left', frameon=False)

# %% [markdown]
# ### 1.3. Multiple plots and Figures
# So far we have used implicit figure and axes creation. This is handy for fast plots. We can have more control over the display using figure, subplot, and axes explicitly. A figure in matplotlib means the whole window in the user interface. Within this figure there can be subplots. While subplot positions the plots in a regular grid, axes allows free placement within the figure. Both can be useful depending on your intention. We've already worked with figures and subplots without explicitly calling them.
#
# #### 1.3.1. Figure
# Figures are numbered starting from 1 as opposed to the normal Python way starting from 0. Various properties can be set for the figures, such as background color, title, etc.
#
# #### 1.3.2. Subplots
# With subplot you can arrange plots in a regular grid. You need to specify the number of rows and columns and the number of the plot. For example in plt.subplot(212), 212  means the figure has 2 rows of subplots, arranged in 1 column, and this subplot is the 2nd plot. This arrangment of the subplots is important, by incorrect values the plots will be hidden.

# %%
fig1=plt.figure(1)
plt.plot(X,C, X,S)
#giving figure a title
fig1.suptitle('Figure1', fontsize=14, fontweight='bold')
#plotting a figure with subplots
fig2=plt.figure(2)
x2=plt.subplot(211, axisbg='black')
x2.plot(X,S, color='white')
x1=plt.subplot(212, axisbg='red')
x1.plot(X,C)
fig2.suptitle('Figure2', fontsize=14, fontstyle='italic')

# %% [markdown]
# #### Exercise 6:
# Plot $y=x^2$ and $y=x^3$ in two subfigures

# %%
x=np.arange(-1,1,0.01)
y2=x**2
y3=x**3

fig=plt.figure()
ax1=plt.subplot(211)
plt.plot(x,y2, 'r')
ax2=plt.subplot(212)
plt.plot(x,y3,'g')

# %% [markdown]
# #### 1.3.3. Sharing Axes
# The subplots in one figure can share either x, or y axes or both of them.

# %%
t = np.arange(0.01, 5.0, 0.01)
s1 = np.sin(2*np.pi*t)
s2 = np.exp(-t)
s3 = np.sin(4*np.pi*t)

ax1 = plt.subplot(311)
plt.plot(t, s1)
plt.setp(ax1.get_xticklabels(), fontsize=6)

# share x only
ax2 = plt.subplot(312, sharex=ax1)
plt.plot(t, s2)
# make these tick labels invisible
plt.setp(ax2.get_xticklabels(), visible=False)

# share x and y
ax3 = plt.subplot(313, sharex=ax1, sharey=ax1)
plt.plot(t, s3)
plt.xlim(0.01, 5.0)
plt.show()

# %% [markdown]
# #### Exercise 7:
# Try to share the x axes of your subplots of Exercise 6:

# %%
x=np.arange(-1,1,0.01)
y2=x**2
y3=x**3

fig=plt.figure()
ax1=plt.subplot(211)
plt.plot(x,y2, 'r')
ax2=plt.subplot(212, sharex=ax1)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.plot(x,y3,'g')

# %% [markdown]
# ### 1.3. Ticks
# Ticks can be defined on axes of a plot with properties as labels, visibility options, etc.

# %%
x = np.linspace(0, 2*np.pi, 50)
y = np.sin(x)
y2 = y + 0.1 * np.random.normal(size=x.shape)

fig, ax = plt.subplots()
ax.plot(x, y, 'k--')

# set ticks and tick labels
ax.set_xlim((0, 2*np.pi))
ax.set_xticks([0, np.pi, 2*np.pi])
ax.set_xticklabels(['0', '$\pi$', '2$\pi$'])
ax.set_ylim((-1.5, 1.5))
ax.set_yticks([-1, 0, 1])

# %% [markdown]
# #### Exercise 8:
# Set ticks values for plot of Exercise 5

# %%
X_t=np.linspace(-np.pi, np.pi)
T=np.arctan(X_t)
fig,ax=plt.subplots()
plt.plot(X_t,T, label='arctan')
plt.ylim(-1.6,1.6)
plt.xlim(-3.5,3.5)
ax.set_xticks([-np.pi,0,np.pi])
ax.set_xticklabels(['$-\pi$', '0', '$\pi$'])
plt.scatter(0,0, 50, color ='red')

plt.annotate(r'$\tan^{-1}(0)=0$',
             xy=(0, 0), xycoords='data',
             xytext=(-80, 20), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.legend(loc='upper left', frameon=False)

# %% [markdown]
# ### 1.4. Spines
# Spines are the lines connecting the axis tick marks and noting the boundaries of the data area. They can be placed at arbitrary positions and by default they are on the border of the axis. We'll change that since we want to have them in the middle. In the exmple below, we will move the left and buttom spines and make the top and right spines invisible.

# %%
fig, ax = plt.subplots()
ax.plot(x, y, 'k--')
# set ticks and tick labels
ax.set_xlim((0, 3*np.pi/2))
ax.set_xticks([0, np.pi/2, np.pi, 3*np.pi/2])
ax.set_xticklabels(['0', '$\pi$/2','$\pi$', '3$\pi$/2'])
ax.set_ylim((-1.5, 1.5))
ax.set_yticks([-1, 0, 1])
ax.spines['left'].set_bounds(-1, 1)
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

# %% [markdown]
# #### Exercise 9:
# move the spines to origin $(0,0)$ on plot of Exercise 8.

# %%
X_t=np.linspace(-np.pi, np.pi)
T=np.arctan(X_t)
fig,ax=plt.subplots()
plt.plot(X_t,T, label='arctan')
plt.ylim(-1.6,1.6)
plt.xlim(-3.5,3.5)
ax.set_xticks([-np.pi,0,np.pi])
ax.set_xticklabels(['$-\pi$', '0', '$\pi$'])
plt.scatter(0,0, 50, color ='red')

plt.annotate(r'$\tan^{-1}(0)=0$',
             xy=(0, 0), xycoords='data',
             xytext=(-80, 20), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.legend(loc='upper left', frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

# %% [markdown]
# ## 3. Other types of plots
#
# ### 3.1.Bar Plots
# Bar plots are quite often used to analyze statistics.**plt.bar()** is special for plotting bars.

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
# Out:
# <Container object of 12 artists>

# %% [markdown]
# #### Aligning bars

# %%
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

#For a greater range of colors, you have two options. You can specify the color using an html hex string, as in:
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
#or you can pass an R , G , B tuple, where each of R , G , B are in the range [0,1].
plt.bar(X, -Y2, facecolor=(0.7,0.2,0.4), edgecolor='black')

for x,y in zip(X,Y1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

plt.ylim(-1.25,1.25)
plt.show()

# %% [markdown]
# #### Exercise 10:
# Generate Y3 set of random numbers and plot the __magenta__ colored bars with width=0.5 on stacked on top of Y1 bars.
# **Hint:** you can specify the startpoint of bar by **bottom**

# %%
Y3 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X+0.125, +Y3, bottom=Y1, width=0.5,facecolor='m', edgecolor='white')
# Out:
# <Container object of 12 artists>

# %% [markdown]
# ### 3.2. Histograms
# in order to plot histograms, **hist()** command of pyplot can be used which also accepts different styling and formatting options as well as alpha value of the plot. **mlab** library of matplotlib contains numerical python functions written for compatability with MATLAB commands with the same names. Commands like **normpdf** of this library can be used to draw the best fit norm of the histogram.

# %%
import matplotlib.mlab as mlab
mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.5)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
#title in latex style
plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
#show the grid lines on the plot
plt.grid(True)

plt.show()

# %% [markdown]
# ### 3.3. Scatter Plots
# **scatter()** makes a scatter plot of x vs y, where x and y are sequence like objects of the same lengths.
# x, y : array of n numbers
# Input data:
# s : size in points^2. , scalar or array of n numbers, optional, default: 20
#
# c : color or sequence of color (optional) , c uses the colormap function to map single value to a color
# alpha: The alpha blending value, between 0 (transparent) and 1 (opaque)

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

plt.axes([0.025,0.025,0.95,0.95])
plt.scatter(X,Y, s=75,alpha=.5)

plt.xlim(-1.5,1.5), plt.xticks([])
plt.ylim(-1.5,1.5), plt.yticks([])

plt.show()

# %% [markdown]
# #### Exercise 11:
# Change the color of points by the angles of x,and y in the scatter plot. **Hint:** use np.arctan2 function

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
T=np.arctan2(Y,X)
plt.axes([0.025,0.025,0.95,0.95])
plt.scatter(X,Y, s=75,c=T,alpha=.5)

plt.xlim(-1.5,1.5), plt.xticks([])
plt.ylim(-1.5,1.5), plt.yticks([])

plt.show()

# %% [markdown]
# ### 3.4. 3D-Plot
# The library Axes3D is used for 3D plotting. By **Axes3D(fig)** the figure is set to be used for 3D plot.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

X = np.arange(-50, 50, 0.2)
Y = np.arange(-50, 50, 0.2)
# generate the mesh points
x, y = np.meshgrid(X, Y)
z= 1-abs(x+y)-abs(y-x) 

ax.plot_surface(x, y, z, cmap='hot')
plt.show()

# %% [markdown]
# #### Exercise 12:
# Plot the equation below in 3D with rainbow color map
# $z=x\exp^{(-x^2-y^2)}$
# $x\in[-2,2]~dx=0.01 \\
# y\in[-2,2]~dy=0.01$

# %%
X=np.arange(-2,2,0.01)
Y=np.arange(-2,2,0.01)
x,y=np.meshgrid(X,Y)

fig=plt.figure()
ax=Axes3D(fig)
z=x*np.exp(-x*x-y*y)
ax.plot_surface(x,y,z, cmap='rainbow')
